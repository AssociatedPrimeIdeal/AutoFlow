# %%
import utils_demo

# --- Input / Output ---
utils_demo.INPUT = [                        # List of H5 file paths or directories to process
    "./data/demo_data.h5", 
]
utils_demo.OUTPUT_DIR = "./results"          # Root output directory for all cases

# --- Pipeline Control ---
utils_demo.SKIP_DERIVED = False              # Skip WSS/TKE derived metric computation
utils_demo.USE_MULTITHREAD = True            # Enable multithreaded plane metric calculation
utils_demo.REUSE_PLANES = ""                 # Path to reuse plane positions (file or dir); empty = generate new

# --- Plane Generation ---
utils_demo.USE_CENTER_PLANE = True           # Place a single center plane per path instead of evenly spaced
utils_demo.CROSS_SECTION_DIST = 15.0        # Spacing (mm) between cross-section planes along each path
utils_demo.START_DIST = 5.0                  # Distance (mm) from path start before first plane
utils_demo.END_DIST = 0.0                    # Distance (mm) from path end to stop placing planes

# --- Skeleton Preprocessing ---
utils_demo.MIN_CC_VOLUME = 50.0              # Minimum connected-component volume (mm³) to keep
utils_demo.REMOVE_SMALL_CC = True            # Remove small connected components from segmask

# --- Video Rendering ---
utils_demo.FPS = 12                          # Frames per second for output videos
utils_demo.PLANE_ROTATION_FRAMES = 180       # Total frames in the plane rotation video (360° orbit)
utils_demo.MAKE_PLANE_VIDEO = True            # Render plane rotation video
utils_demo.MAKE_WSS_VIDEO = True              # Render WSS time-series video
utils_demo.MAKE_STREAMLINES_VIDEO = True      # Render streamlines time-series video
utils_demo.MAKE_TKE_VIDEO = True              # Render TKE time-series video

# --- Camera ---
utils_demo.CAMERA_VIEW = "right"             # Camera preset: iso/iso_back/right/left/anterior/posterior/superior/inferior
utils_demo.CAMERA_DISTANCE_SCALE = 1.5       # Multiplier for camera distance from scene center

# --- Annotation ---
utils_demo.ADD_PLANE_IDX = False             # Show plane index labels in plane video
utils_demo.ADD_PATH_IDX = True               # Show branch index labels in plane video

# --- Colormap Ranges & Scalar Bar Layout ---
utils_demo.WSS_CLIM = (0, 5)                # WSS color range (Pa)
utils_demo.WSS_BAR_CFG = {"position_x": 0.7, "position_y": 0.1, "height": 0.22, "width": 0.05, "title_font_size": 40, "label_font_size": 32}  # WSS scalar bar position/size
utils_demo.TKE_CLIM = (0, 100)              # TKE color range (J/m³)
utils_demo.TKE_BAR_CFG = {"position_x": 0.7, "position_y": 0.1, "height": 0.22, "width": 0.05, "title_font_size": 40, "label_font_size": 32}  # TKE scalar bar position/size
utils_demo.STREAMLINE_CLIM = (0, 1.5)       # Streamline velocity color range (m/s)
utils_demo.STREAMLINE_BAR_CFG = {"position_x": 0.7, "position_y": 0.1, "height": 0.22, "width": 0.05, "title_font_size": 40, "label_font_size": 32}  # Streamline scalar bar position/size

# --- Streamline Seeding ---
utils_demo.SEED_RATIO = 0.05                # Fraction of mask voxels used as streamline seed points

# --- Run ---
results, case_out = utils_demo.run_batch()
# Out:
# Found 1 file(s) to process.
#
# ============================================================
# Processing: ./data/demo_data.h5
# Output dir: ./results/demo_data
# ============================================================
# [1/7] Loading data...
#   [LOG] Loaded: segmask=(34, 50, 104, 17) labels=[1] rr=1000.0 flow=(34, 50, 104, 17, 3) mag=(34, 50, 104, 17) origin=[0.0, 0.0, 0.0]
#   -> Step 1 took 1.61s
# [2/7] Generate Skeleton...
#   -> Skeleton: 198 points
#   -> Step 2 took 0.03s
# [3/7] Generate Graph (+ branches/forks)...
#   -> Graph: 198 nodes, 197 edges | paths=7 forks=3
#   -> Step 3 took 0.06s
# [4/7] Generate Planes...
#   -> Planes: 7 paths=7 forks=3 saved=./results/demo_data/planes.json | Plane metrics: 7 paths=7 forks=3
#   -> Step 4 took 2.54s
# [5/7] Use generated planes
#   -> Step 5 took 0.00s
# [6/7] Calculate & Save Metrics...
#   -> Plane metrics: 7 paths=7 forks=3 saved=./results/demo_data/plane_metrics.json qc=./results/demo_data/plane_qc.json
#   -> Step 6 took 0.65s
# [7/7] Compute Derived Metrics (WSS/TKE)...
#   -> Saved pixelwise: ./results/demo_data/derived_metrics_pixelwise.npz
#   -> Derived: Nt=17
#   -> Step 7 took 1.72s
#   => Total pipeline took 6.62s
# Plane positions saved: ./results/demo_data/plane_positions.json
# /home/renyuyang/miniconda3/envs/ryy/lib/python3.9/site-packages/pyvista/plotting/utilities/xvfb.py:48: PyVistaDeprecationWarning: This function is deprecated and will be removed in future version of PyVista. Use vtk-osmesa instead.
#   warnings.warn(
# 2026-04-12 02:30:10.989 (   7.666s) [    750CD53D9740]vtkXOpenGLRenderWindow.:1458  WARN| bad X server connection. DISPLAY=
# /home/renyuyang/miniconda3/envs/ryy/lib/python3.9/site-packages/imageio_ffmpeg/_utils.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# Plane video saved: ./results/demo_data/planes_rotate.mp4
# /home/renyuyang/miniconda3/envs/ryy/lib/python3.9/site-packages/pyvista/plotting/utilities/xvfb.py:48: PyVistaDeprecationWarning: This function is deprecated and will be removed in future version of PyVista. Use vtk-osmesa instead.
#   warnings.warn(
# Streamlines video saved: ./results/demo_data/streamlines_video.mp4
# WSS video saved: ./results/demo_data/wss_video.mp4
# TKE video saved: ./results/demo_data/tke_video.mp4
#
#   === Plane Metrics Summary ===
#    Plane  Path  Net Flow(mL/beat)  Peak Velocity(cm/s)  Mean Velocity(cm/s)     IC
#   ------ -----  ------------------ -------------------- -------------------- ------
#        0     0             4.4191               27.890                6.872  1.000
#        1     1            25.0148               58.677                6.312  1.000
#        2     2            35.3197               66.582                7.170  1.000
#        3     3            63.1978              126.381                6.034  1.000
#        4     4            38.1151               98.507                6.977  1.000
#        5     5             3.8731               37.668                8.573  1.000
#        6     6             2.4242               35.828               10.487  1.000
#
#   === Fork QC Summary ===
#     Fork     Internal Consistency                     Left                    Right
#   ------ ------------------------ ------------------------ ------------------------
#        0                 0.545228                  Branch1          Branch0+Branch2
#        1                 0.596722                  Branch3          Branch4+Branch5
#        2                 0.674279                  Branch4          Branch1+Branch6
#
# Summary saved: ./results/demo_data/summary.json
#
# Case time: 6.62 ± 0.00 s
#
# Done: 1/1 succeeded. Report: ./results/batch_report.json

# %%
import utils_demo

# --- Input / Output ---
utils_demo.INPUT = [                        # List of H5 file paths or directories to process
    "./data/phantom_S.h5",
    "./data/phantom_U.h5",
    "./data/phantom_Y.h5",
]
utils_demo.OUTPUT_DIR = "./results"          # Root output directory for all cases

# --- Pipeline Control ---
utils_demo.SKIP_DERIVED = False              # Skip WSS/TKE derived metric computation
utils_demo.USE_MULTITHREAD = True            # Enable multithreaded plane metric calculation
utils_demo.REUSE_PLANES = ""                 # Path to reuse plane positions (file or dir); empty = generate new
utils_demo.MAKE_PLANE_VIDEO = False            # Render plane rotation video
utils_demo.MAKE_WSS_VIDEO = False              # Render WSS time-series video
utils_demo.MAKE_STREAMLINES_VIDEO = False      # Render streamlines time-series video
utils_demo.MAKE_TKE_VIDEO = False              # Render TKE time-series video
# --- Plane Generation ---
utils_demo.USE_CENTER_PLANE = False           # Place a single center plane per path instead of evenly spaced
utils_demo.CROSS_SECTION_DIST = 5.0        # Spacing (mm) between cross-section planes along each path

# --- Annotation ---
utils_demo.ADD_PLANE_IDX = False             # Show plane index labels in plane video
utils_demo.ADD_PATH_IDX = False               # Show branch index labels in plane video

# --- Run ---
results, case_out = utils_demo.run_batch()
# Out:
# Found 3 file(s) to process.
#
# ============================================================
# Processing: ./data/phantom_S.h5
# Output dir: ./results/phantom_S
# ============================================================
# [1/7] Loading data...
#   [LOG] Loaded: segmask=(15, 15, 95, 20) labels=[1] rr=900.0 flow=(15, 15, 95, 20, 3) mag=(15, 15, 95, 20) origin=[0.0, 0.0, 0.0]
#   -> Step 1 took 0.18s
# [2/7] Generate Skeleton...
#   -> Skeleton: 79 points
#   -> Step 2 took 0.01s
# [3/7] Generate Graph (+ branches/forks)...
#   -> Graph: 79 nodes, 78 edges | paths=1 forks=0
#   -> Step 3 took 0.01s
# [4/7] Generate Planes...
#   -> Planes: 15 paths=1 forks=0 saved=./results/phantom_S/planes.json | Plane metrics: 15 paths=1 forks=0
#   -> Step 4 took 2.58s
# [5/7] Use generated planes
#   -> Step 5 took 0.00s
# [6/7] Calculate & Save Metrics...
#   -> Plane metrics: 15 paths=1 forks=0 saved=./results/phantom_S/plane_metrics.json qc=./results/phantom_S/plane_qc.json
#   -> Step 6 took 2.41s
# [7/7] Compute Derived Metrics (WSS/TKE)...
#   -> Saved pixelwise: ./results/phantom_S/derived_metrics_pixelwise.npz
#   -> Derived: Nt=20
#   -> Step 7 took 0.76s
#   => Total pipeline took 5.94s
# Plane positions saved: ./results/phantom_S/plane_positions.json
#
#   === Plane Metrics Summary ===
#    Plane  Path  Net Flow(mL/beat)  Peak Velocity(cm/s)  Mean Velocity(cm/s)     IC
#   ------ -----  ------------------ -------------------- -------------------- ------
#        0     0            16.0409               80.000               22.004  1.000
#        1     0            16.0409               80.000               22.004  1.000
#        2     0            16.0409               80.000               22.004  1.000
#        3     0            16.0409               80.000               22.004  1.000
#        4     0            16.0409               80.000               22.004  1.000
#        5     0            16.0409               80.000               22.004  1.000
#        6     0            16.0409               80.000               22.004  1.000
#        7     0            16.0409               80.000               22.004  1.000
#        8     0            16.0409               80.000               22.004  1.000
#        9     0            16.0409               80.000               22.004  1.000
#       10     0            16.0409               80.000               22.004  1.000
#       11     0            16.0409               80.000               22.004  1.000
#       12     0            16.0409               80.000               22.004  1.000
#       13     0            16.0409               80.000               22.004  1.000
#       14     0            16.0409               80.000               22.004  1.000
#
#   === Fork QC Summary ===
#   No fork-level QC results found.
# {
#   "path_ic": {
#     "0": 0.9999999999999998
#   },
#   "fork_ic": {},
#   "forks": []
# }
#
# Summary saved: ./results/phantom_S/summary.json
#
# ============================================================
# Processing: ./data/phantom_U.h5
# Output dir: ./results/phantom_U
# ============================================================
# [1/7] Loading data...
#   [LOG] Loaded: segmask=(45, 15, 70, 20) labels=[1] rr=900.0 flow=(45, 15, 70, 20, 3) mag=(45, 15, 70, 20) origin=[0.0, 0.0, 0.0]
#   -> Step 1 took 0.28s
# [2/7] Generate Skeleton...
#   -> Skeleton: 121 points
#   -> Step 2 took 0.01s
# [3/7] Generate Graph (+ branches/forks)...
#   -> Graph: 121 nodes, 120 edges | paths=1 forks=0
#   -> Step 3 took 0.02s
# [4/7] Generate Planes...
#   -> Planes: 24 paths=1 forks=0 saved=./results/phantom_U/planes.json | Plane metrics: 24 paths=1 forks=0
#   -> Step 4 took 4.59s
# [5/7] Use generated planes
#   -> Step 5 took 0.00s
# [6/7] Calculate & Save Metrics...
#   -> Plane metrics: 24 paths=1 forks=0 saved=./results/phantom_U/plane_metrics.json qc=./results/phantom_U/plane_qc.json
#   -> Step 6 took 5.72s
# [7/7] Compute Derived Metrics (WSS/TKE)...
#   -> Saved pixelwise: ./results/phantom_U/derived_metrics_pixelwise.npz
#   -> Derived: Nt=20
#   -> Step 7 took 1.17s
#   => Total pipeline took 11.78s
# Plane positions saved: ./results/phantom_U/plane_positions.json
#
#   === Plane Metrics Summary ===
#    Plane  Path  Net Flow(mL/beat)  Peak Velocity(cm/s)  Mean Velocity(cm/s)     IC
#   ------ -----  ------------------ -------------------- -------------------- ------
#        0     0            16.0409               80.000              -22.004  0.998
#        1     0            16.0409               80.000              -22.004  0.998
#        2     0            16.0409               80.000              -22.004  0.998
#        3     0            16.0409               80.000              -22.004  0.998
#        4     0            16.0409               80.000              -22.004  0.998
#        5     0            16.0409               79.945              -21.989  0.998
#        6     0            16.0409               79.232              -21.793  0.998
#        7     0            16.0711               79.891               24.127  0.998
#        8     0            16.0409               76.031              -20.912  0.998
#        9     0            16.0409               58.422              -16.069  0.998
#       10     0            16.0122               35.526               -9.962  0.998
#       11     0            16.2202               77.860               23.104  0.998
#       12     0            16.2163               79.389               23.707  0.998
#       13     0            16.0409               37.616              -10.346  0.998
#       14     0            16.0409               63.282              -17.406  0.998
#       15     0            16.0409               73.372              -20.181  0.998
#       16     0            16.0409               79.691              -21.919  0.998
#       17     0            16.0409               80.000               22.004  0.998
#       18     0            16.0409               80.000               22.004  0.998
#       19     0            16.0409               80.000               22.004  0.998
#       20     0            16.0409               80.000               22.004  0.998
#       21     0            16.0409               80.000               22.004  0.998
#       22     0            16.0409               80.000               22.004  0.998
#       23     0            16.0409               80.000               22.004  0.998
#
#   === Fork QC Summary ===
#   No fork-level QC results found.
# {
#   "path_ic": {
#     "0": 0.9982335565087015
#   },
#   "fork_ic": {},
#   "forks": []
# }
#
# Summary saved: ./results/phantom_U/summary.json
#
# ============================================================
# Processing: ./data/phantom_Y.h5
# Output dir: ./results/phantom_Y
# ============================================================
# [1/7] Loading data...
#   [LOG] Loaded: segmask=(76, 15, 63, 20) labels=[1] rr=900.0 flow=(76, 15, 63, 20, 3) mag=(76, 15, 63, 20) origin=[0.0, 0.0, 0.0]
#   -> Step 1 took 0.62s
# [2/7] Generate Skeleton...
#   -> Skeleton: 89 points
#   -> Step 2 took 0.02s
# [3/7] Generate Graph (+ branches/forks)...
#   -> Graph: 89 nodes, 88 edges | paths=3 forks=1
#   -> Step 3 took 0.05s
# [4/7] Generate Planes...
#   -> Planes: 19 paths=3 forks=1 saved=./results/phantom_Y/planes.json | Plane metrics: 19 paths=3 forks=1
#   -> Step 4 took 4.57s
# [5/7] Use generated planes
#   -> Step 5 took 0.00s
# [6/7] Calculate & Save Metrics...
#   -> Plane metrics: 19 paths=3 forks=1 saved=./results/phantom_Y/plane_metrics.json qc=./results/phantom_Y/plane_qc.json
#   -> Step 6 took 3.70s
# [7/7] Compute Derived Metrics (WSS/TKE)...
#   -> Saved pixelwise: ./results/phantom_Y/derived_metrics_pixelwise.npz
#   -> Derived: Nt=20
#   -> Step 7 took 1.31s
#   => Total pipeline took 10.27s
# Plane positions saved: ./results/phantom_Y/plane_positions.json
#
#   === Plane Metrics Summary ===
#    Plane  Path  Net Flow(mL/beat)  Peak Velocity(cm/s)  Mean Velocity(cm/s)     IC
#   ------ -----  ------------------ -------------------- -------------------- ------
#        0     0            16.0409               80.000               22.004  1.000
#        1     0            16.0409               80.000               22.004  1.000
#        2     0            16.0409               80.000               22.004  1.000
#        3     0            16.0409               80.000               22.004  1.000
#        4     0            16.0409               80.000               22.004  1.000
#        5     0            16.0409               80.000               22.004  1.000
#        6     0            16.0409               80.000               22.004  1.000
#        7     1             8.1160               39.929               12.057  0.998
#        8     1             8.1245               39.999               11.439  0.998
#        9     1             8.0896               40.000               12.026  0.998
#       10     1             8.1324               40.000               11.308  0.998
#       11     1             8.0813               40.000               12.178  0.998
#       12     1             8.1357               40.000               11.257  0.998
#       13     2             8.1075               39.929               11.471  0.998
#       14     2             8.0946               39.999               11.945  0.998
#       15     2             8.1283               40.000               11.373  0.998
#       16     2             8.0855               40.000               12.101  0.998
#       17     2             8.1366               40.000               11.243  0.998
#       18     2             8.0822               40.000               12.161  0.998
#
#   === Fork QC Summary ===
#     Fork     Internal Consistency                     Left                    Right
#   ------ ------------------------ ------------------------ ------------------------
#        0                 0.988954                  Branch0          Branch1+Branch2
#
# Summary saved: ./results/phantom_Y/summary.json
#
# Case time: 9.33 ± 3.03 s
#
# Done: 3/3 succeeded. Report: ./results/batch_report.json
